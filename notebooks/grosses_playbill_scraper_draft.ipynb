# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup as BS
from IPython.core.display import HTML
from datetime import datetime

# %%
gross_URL = 'https://www.playbill.com/grosses'
gross_response = requests.get(gross_URL)

# %%
type(gross_response)
# Out:
# requests.models.Response

# %%
gross_response.status_code
# Out:
# 200

# %%
gross_soup = BS(gross_response.text)
type(gross_soup)
# Out:
# bs4.BeautifulSoup

# %%
print(gross_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://www.playbill.com/assets/images/favicon.jpeg?id=5fe1d70b15ee1de3c27e" rel="icon"/>
#   <link href="https://www.playbill.com/assets/css/main.css?id=41ee54607b58a07edef0" rel="stylesheet" type="text/css"/>
#   <link href="https://www.playbill.com/assets/css/styles.css?id=5e32643b9e5467a6de46" rel="stylesheet"/>
#   <script src="/assets/scripts/main.min.d77d068f800b7d4d0e28dd0efad7f0ca.gz.js">
#   </script>
#   <script src="https://www.playbill.com/assets/js/flickity.js?id=bbf6f2eb8a0ed13f347f">
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
# ...

# %% [markdown]
# ##### brainstorming cell
# create URL altering variable to subtract 7 days
# figure out how to pull multiple tags in one for loop, perhaps appending into a dictionary?...
