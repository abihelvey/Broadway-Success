# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns

# %%
gross = pd.read_excel('../data/excel-full-data.xlsx')
gross.head()
# Out:
#    Unnamed: 0             Title                       Theater  Weekly Gross  \
# 0           0    A Strange Loop                Lyceum Theatre     676315.50
# 1           1           Aladdin         New Amsterdam Theatre    1273005.65
# 2           2  American Buffalo  Circle in the Square Theatre     460041.96
# 3           3       Beetlejuice               Marquis Theatre    1160587.50
# 4           4           Chicago            Ambassador Theatre     548919.39
#
#    Potential Gross  Gross Difference (Calculated)  Average Ticket Price  \
# 0              NaN                            NaN                108.23
# 1              NaN                            NaN                 96.74
# 2              NaN                            NaN                102.73
# 3              NaN                            NaN                117.59
# 4              NaN                            NaN                 89.18
#
#    Top Ticket Price  Seats Sold  Theater Capacity  Percent Capacity  \
# ...

# %%
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17120 entries, 0 to 17119
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        17120 non-null  int64
#  1   Title                             17120 non-null  object
#  2   Theater                           17120 non-null  object
#  3   Weekly Gross                      17120 non-null  float64
#  4   Potential Gross                   16078 non-null  float64
#  5   Gross Difference (Calculated)     16078 non-null  float64
#  6   Average Ticket Price              17120 non-null  float64
#  7   Top Ticket Price                  16494 non-null  float64
#  8   Seats Sold                        17120 non-null  int64
#  9   Theater Capacity                  17120 non-null  int64
#  10  Percent Capacity                  17120 non-null  float64
# ...

# %%
top_10_titles = ['The Lion King', 'Wicked', 'The Phantom of the Opera', 'Hamilton', 'Chicago', 'The Book of Mormon', 'Mamma Mia!', 'Jersey Boys', 'Aladdin', 'Cats']
top_10_grosses = [1740000000, 1430000000, 1300000000, 727840000, 700750000, 687180000, 624400000, 558420000, 492890000, 432000000]
top_10_tickets = [16140000, 12700000, 19600000, 2950000, 9710000, 4320000, 7600000, 5200000, 4630000, 9330000]
top_10_avg_price = [108, 112, 55, 247, 73, 158, 82, 107, 106, 20]
top_10_perf_count = [9600, 7128, 13611, 2205, 9977, 3993, 5772, 4680, 2758, 7401]
top_10_status = ['Open', 'Open', 'Open', 'Open', 'Revived', 'Open', 'Closed', 'Closed', 'Open', 'Closed']
top_10_gross = pd.DataFrame()
top_10_gross['Title'] = top_10_titles
top_10_gross['Total Gross Revenue'] = top_10_grosses
top_10_gross['Total Tickets Sold'] = top_10_tickets
top_10_gross['Average Ticket Price'] = top_10_avg_price
top_10_gross['Performance Count'] = top_10_perf_count
top_10_gross['Open/Closed?'] = top_10_status
top_10_gross
# Out:
#                       Title  Total Gross Revenue  Total Tickets Sold  \
# 0             The Lion King           1740000000            16140000
# 1                    Wicked           1430000000            12700000
# 2  The Phantom of the Opera           1300000000            19600000
# 3                  Hamilton            727840000             2950000
# 4                   Chicago            700750000             9710000
# 5        The Book of Mormon            687180000             4320000
# 6                Mamma Mia!            624400000             7600000
# 7               Jersey Boys            558420000             5200000
# 8                   Aladdin            492890000             4630000
# 9                      Cats            432000000             9330000
#
#    Average Ticket Price  Performance Count Open/Closed?
# 0                   108               9600         Open
# 1                   112               7128         Open
# ...

# %%
top_10_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 10 non-null     object
#  1   Total Gross Revenue   10 non-null     int64
#  2   Total Tickets Sold    10 non-null     int64
#  3   Average Ticket Price  10 non-null     int64
#  4   Performance Count     10 non-null     int64
#  5   Open/Closed?          10 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 608.0+ bytes

# %%
plt.figure(figsize=(15, 10))
plt.barh(top_10_gross['Title'], top_10_gross['Total Gross Revenue'], color='r')
plt.title('Highest-Grossing Broadway Shows', fontsize=20)
plt.yticks(fontsize=16)
plt.xlabel('Total Gross (in billions of dollars)', fontsize=16)
plt.xticks(rotation=20, fontsize=14)
#ax.bar_label(ax.containers[0], size=12, padding=3, fmt='%.2f')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.scatter(top_10_gross['Total Gross Revenue'], top_10_gross['Total Tickets Sold'], color='r', s=100)
plt.title('Total Revenue vs. Total Tickets Sold', fontsize=20)
plt.ylabel('Total Tickets Sold (in ten-millions)', fontsize=16)
plt.xlabel('Total Gross Revenue (in billions of dollars)', fontsize=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.scatter(top_10_gross['Total Gross Revenue'], top_10_gross['Average Ticket Price'], color='r', s=100)
plt.title('Total Revenue vs. Average Ticket Price', fontsize=20)
plt.ylabel('Average Ticket Price (in dollars)', fontsize=16)
plt.xlabel('Total Gross Revenue (in billions of dollars)', fontsize=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()

# %%
theatres = pd.read_csv('../data/theatre_data.csv')
theatres.head()
# Out:
#                  Address  Capacity                    Theatre  \
# 0  W. 41st St. (No. 208)      1235        Nederlander Theatre
# 1  W. 42nd St. (No. 214)      1747      New Amsterdam Theatre
# 2  W. 42nd St. (No. 227)       740  American Airlines Theatre
# 3  W. 43rd St. (No. 124)      1055   Stephen Sondheim Theatre
# 4  W. 43rd St. (No. 214)      1622              Lyric Theatre
#
#                Owner/Operator     Type
# 0    Nederlander Organization  Musical
# 1     Disney Theatrical Group  Musical
# 2  Roundabout Theatre Company  Musical
# 3  Roundabout Theatre Company      NaN
# 4    Ambassador Theatre Group     Play

# %%
theatres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Address         41 non-null     object
#  1   Capacity        41 non-null     int64
#  2   Theatre         41 non-null     object
#  3   Owner/Operator  41 non-null     object
#  4   Type            37 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.7+ KB

# %%
theatres.sort_values(by=['Capacity'], ascending=False, inplace=True)
theatres.head()
# Out:
#                               Address  Capacity                Theatre  \
# 35              W. 51st St. (No. 222)      1933       Gershwin Theatre
# 38   W. 53rd St & Broadway (No. 1681)      1761       Broadway Theatre
# 1               W. 42nd St. (No. 214)      1747  New Amsterdam Theatre
# 24  W. 47th St. & Broadway (No. 1564)      1743         Palace Theatre
# 13              W. 45th St. (No. 200)      1710       Minskoff Theatre
#
#               Owner/Operator  \
# 35  Nederlander Organization
# 38      Shubert Organization
# 1    Disney Theatrical Group
# 24  Nederlander Organization
# 13  Nederlander Organization
#
#                                                  Type
# 35                                            Musical
# 38                                                NaN
# 1                                             Musical
# 24  ZzThe Palace Theatre closed for renovation in ...
# 13                                            Musical

# %%
theatres.tail()
# Out:
#                   Address  Capacity                     Theatre  \
# 19  W. 45th St. (No. 252)       805         John Golden Theatre
# 14  W. 45th St. (No. 222)       766               Booth Theatre
# 2   W. 42nd St. (No. 227)       740   American Airlines Theatre
# 27  W. 47th St. (No. 261)       650  Samuel J. Friedman Theatre
# 9   W. 44th St. (No. 240)       597               Hayes Theater
#
#                 Owner/Operator     Type
# 19        Shubert Organization     Play
# 14        Shubert Organization  Musical
# 2   Roundabout Theatre Company  Musical
# 27      Manhattan Theatre Club     Play
# 9         Second Stage Theater     Play

# %%
theatres_10big = theatres.iloc[0:10]
theatres_10big.sort_values(by=['Capacity'], ascending=True, inplace=True)
theatres_10big.reset_index(inplace=True)
theatres_10big
# Out:
# C:\Users\ating\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#    index                            Address  Capacity                Theatre  \
# 0     33  W. 50th St. & Broadway (No. 1634)      1526  Winter Garden Theatre
# 1     22              W. 46th St. (No. 210)      1612        Marquis Theatre
# 2      4              W. 43rd St. (No. 214)      1622          Lyric Theatre
# 3     10              W. 44th St. (No. 245)      1645       Majestic Theatre
# 4     11              W. 44th St. (No. 246)      1709      St. James Theatre
# 5     13              W. 45th St. (No. 200)      1710       Minskoff Theatre
# 6     24  W. 47th St. & Broadway (No. 1564)      1743         Palace Theatre
# ...

# %%
theatres_10small = theatres.iloc[31:41]
theatres_10small.sort_values(by=['Capacity'], ascending=True, inplace=True)
theatres_10small.reset_index(inplace=True)
theatres_10small
# Out:
# C:\Users\ating\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#    index                Address  Capacity                       Theatre  \
# 0      9  W. 44th St. (No. 240)       597                 Hayes Theater
# 1     27  W. 47th St. (No. 261)       650    Samuel J. Friedman Theatre
# 2      2  W. 42nd St. (No. 227)       740     American Airlines Theatre
# 3     14  W. 45th St. (No. 222)       766                 Booth Theatre
# 4     19  W. 45th St. (No. 252)       805           John Golden Theatre
# 5     34  W. 50th St. (No. 235)       840  Circle in the Square Theatre
# 6     12  W. 45th St. (No. 149)       922                Lyceum Theatre
# ...

# %%
plt.figure(figsize=(15,10))
plt.barh(theatres_10big['Theatre'], theatres_10big['Capacity'], color='r')
plt.title('10 Largest Broadway Theatres', fontsize=20)
plt.xlabel('Seat Capacity', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=14)
plt.axvline(x=500, color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.barh(theatres_10small['Theatre'], theatres_10small['Capacity'], color='r')
plt.title('10 Smallest Broadway Theatres', fontsize=20)
plt.xlabel('Seat Capacity', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=14)
plt.axvline(x=500, color='black')
plt.show()

# %%
#this didn't do what I wanted, skipping for now
top_10 = pd.merge(top_10_gross, gross, on='Title', how='left')
top_10.groupby(by='Title')
top_10.head()
# Out:
#            Title  Total Gross Revenue  Total Tickets Sold  \
# 0  The Lion King           1740000000            16140000
# 1  The Lion King           1740000000            16140000
# 2  The Lion King           1740000000            16140000
# 3  The Lion King           1740000000            16140000
# 4  The Lion King           1740000000            16140000
#
#    Average Ticket Price_x  Performance Count_x Open/Closed?  Unnamed: 0  \
# 0                     108                 9600         Open          25
# 1                     108                 9600         Open          55
# 2                     108                 9600         Open          89
# 3                     108                 9600         Open         124
# 4                     108                 9600         Open         159
#
#             Theater  Weekly Gross  Potential Gross  ...  \
# 0  Minskoff Theatre     1951072.0              NaN  ...
# 1  Minskoff Theatre     1864584.0              NaN  ...
# ...

# %%
theatres['Average Ticket Price'] = gross.groupby('Theater')['Average Ticket Price'].mean()
theatres.head()
# Out:
#                               Address  Capacity                Theatre  \
# 35              W. 51st St. (No. 222)      1933       Gershwin Theatre
# 38   W. 53rd St & Broadway (No. 1681)      1761       Broadway Theatre
# 1               W. 42nd St. (No. 214)      1747  New Amsterdam Theatre
# 24  W. 47th St. & Broadway (No. 1564)      1743         Palace Theatre
# 13              W. 45th St. (No. 200)      1710       Minskoff Theatre
#
#               Owner/Operator  \
# 35  Nederlander Organization
# 38      Shubert Organization
# 1    Disney Theatrical Group
# 24  Nederlander Organization
# 13  Nederlander Organization
#
#                                                  Type  Average Ticket Price  \
# 35                                            Musical                   NaN
# 38                                                NaN                   NaN
# 1                                             Musical                   NaN
# ...

# %%
gross['Theater Show Count'] = gross.groupby('Theater')['Title'].count()
gross.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4676/1357522124.py in <module>
# ----> 1 gross['Theater Show Count'] = gross.groupby('Theater')['Title'].count(skipna=True)
#       2 gross.head()
#
# TypeError: count() got an unexpected keyword argument 'skipna'

# %%
plt.figure(figsize=(15, 10))
plt.scatter(gross['Theater Capacity'], gross['Average Ticket Price'], color='r', s=100)
plt.title('Theater Capacity vs. Average Ticket Price', fontsize=20)
plt.ylabel('Average Ticket Price (in dollars)', fontsize=16)
plt.xlabel('Theater Capacity', fontsize=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.scatter(gross['Theater Capacity'], gross['Top Ticket Price'], color='r', s=100)
plt.title('Theater Capacity vs. Top Ticket Price', fontsize=20)
plt.ylabel('Top Ticket Price (in dollars)', fontsize=16)
plt.xlabel('Theater Capacity', fontsize=16)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.show()
